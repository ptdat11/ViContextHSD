# %%
# Test forward
# !python3 test_forward.py \
    --model=additive \
    --tokenizer=whitespace \
    --ablate=none \
    --batch-size=16
# Out:
# ...
# Processing comment: 100%|██████████| 13451/13451 [00:03<00:00, 4362.50comment/s]
# ...
# Layer (type:depth-idx)                   Param #
# ...
# ├─Embedding: 1-1                         9,878,016
# ├─LSTM: 1-2                              23,617,536
# ├─LSTM: 1-3                              23,617,536
# ├─Sequential: 1-4                        --
# |    └─Conv2d: 2-1                       448
# |    └─BatchNorm2d: 2-2                  32
# |    └─ReLU: 2-3                         --
# |    └─MaxPool2d: 2-4                    --
# |    └─Conv2d: 2-5                       4,640
# |    └─BatchNorm2d: 2-6                  64
# |    └─ReLU: 2-7                         --
# |    └─MaxPool2d: 2-8                    --
# |    └─Conv2d: 2-9                       18,496
# |    └─BatchNorm2d: 2-10                 128
# |    └─ReLU: 2-11                        --
# |    └─MaxPool2d: 2-12                   --
# |    └─Flatten: 2-13                     --
# ├─Sequential: 1-5                        --
# ...

# %%
# Train model
# !python3 train.py \
    --model=additive \
    --tokenizer=whitespace \
    --ablate=none \
    --epochs=10 \
    --batch-size=32 \
    --learning-rate=5e-4 \
    --weight-decay=0 \
    --grad-accum=1 \
    # --amp=False \
    --resume=none
# Out:
# INFO: Using device cuda
# INFO: Loading datasets...
# INFO: Building tokenizer
# ...
# Layer (type:depth-idx)                   Param #
# ...
# ├─Embedding: 1-1                         9,475,584
# ├─LSTM: 1-2                              23,617,536
# ├─LSTM: 1-3                              23,617,536
# ├─Sequential: 1-4                        --
# |    └─Conv2d: 2-1                       448
# |    └─BatchNorm2d: 2-2                  32
# |    └─ReLU: 2-3                         --
# |    └─MaxPool2d: 2-4                    --
# |    └─Conv2d: 2-5                       4,640
# |    └─BatchNorm2d: 2-6                  64
# |    └─ReLU: 2-7                         --
# |    └─MaxPool2d: 2-8                    --
# |    └─Conv2d: 2-9                       18,496
# |    └─BatchNorm2d: 2-10                 128
# |    └─ReLU: 2-11                        --
# |    └─MaxPool2d: 2-12                   --
# |    └─Flatten: 2-13                     --
# ├─Sequential: 1-5                        --
# ...
